# %% [markdown]
# <a href="https://colab.research.google.com/github/ZetiAi/library/blob/master/stable_diffusion_1_5_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install libraries
# !pip install torch
# !pip install transformers
# !pip install diffusers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.3 MB 4.8 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 66.8 MB/s
# ...
#      |████████████████████████████████| 163 kB 84.6 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 255 kB 4.9 MB/s
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch

# %%
# !huggingface-cli login
# Out:
#         _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#         _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#         _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#         _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#         _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#         To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#
# Token:
# Login successful
# Your token has been saved to /root/.huggingface/token
# Authenticated through git-credential store but this isn't the helper defined on your machine.
# ...

# %%
# !git config --global credential.helper.store

# %%
def dummy(images, **kwargs):
    return images, False

# %%
model_id = "runwayml/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16, revision="fp16")
pipe = pipe.to("cuda")
# Out:
# Downloading:   0%|          | 0.00/543 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.70k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/608M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/284 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/636 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/246M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/525k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/472 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/822 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/806 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.72G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/609 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/167M [00:00<?, ?B/s]
# ...

# %%
prompt = "A Polar bear looking sad as he stares as a ice on fire in front of him, 35mm photo, highly realistic, highly detailed"
image = pipe(prompt).images[0]
image
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FEF9B368510>

# %%
prompt = "Narendra Modi shaking hands with Xi Jinping, 35mm photo, highly realistic, highly detailed"
image = pipe(prompt).images[0]
image
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F8D00794650>

# %%
prompt = "People working together in an office on computers, no faces, digital art, vector image, bright colors"
image = pipe(prompt).images[0]
image
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F8D007C3210>

# %%
prompt = "A robot with a cape flying to the cloud with a paper scroll, digital art, vector image, friendly, bright colors"
image = pipe(prompt, height=512, width=512).images[0]
image
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F8D0068A350>
